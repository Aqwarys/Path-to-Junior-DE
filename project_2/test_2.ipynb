# %%
import pandas as pd
from pathlib import Path

# %%
df = pd.read_csv("data/processed/cleaned_20251107-f811c279-f2ba-4c66-94c5-c1b6f4d2bff8.csv", encoding="utf-8")

# %%
df.dtypes
# епизоды надо в INT
# aired надо в дату
# genres посмотреть
# title, title_japanese конвертнуть в str
# Out:
# mal_id              int64
# url                object
# trailer            object
# title              object
# title_japanese     object
# type               object
# source             object
# episodes            int64
# status             object
# aired              object
# duration           object
# rating             object
# score             float64
# members             int64
# favorites           int64
# genres             object
# year                int64
# dtype: object

# %%
df.iloc[0]
# Out:
# mal_id                                                        52991
# url               https://myanimelist.net/anime/52991/Sousou_no_...
# trailer           https://www.youtube-nocookie.com/embed/ZEkwCGJ...
# title                                             Sousou no Frieren
# title_japanese                                             葬送のフリーレン
# type                                                             TV
# source                                                        Manga
# episodes                                                       28.0
# status                                              Finished Airing
# aired                                  Sep 29, 2023 to Mar 22, 2024
# duration                                              24 min per ep
# rating                                    PG-13 - Teens 13 or older
# score                                                          9.29
# members                                                     1248797
# ...

# %%
df_na=df[df["title_japanese"].isna()]
df_na
# Out:
# Empty DataFrame
# Columns: [mal_id, url, trailer, title, title_japanese, type, source, episodes, status, aired, duration, rating, score, members, favorites, genres, year]
# Index: []
