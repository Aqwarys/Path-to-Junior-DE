# %%
import pandas as pd

# %%
df = pd.read_csv("data/raw/data.csv", encoding="utf-8")
df
# Out:
#      mal_id                                                url  \
# 0     52991  https://myanimelist.net/anime/52991/Sousou_no_...
# 1     57555  https://myanimelist.net/anime/57555/Chainsaw_M...
# 2      5114  https://myanimelist.net/anime/5114/Fullmetal_A...
# 3      9253     https://myanimelist.net/anime/9253/Steins_Gate
# 4     38524  https://myanimelist.net/anime/38524/Shingeki_n...
# ..      ...                                                ...
# 295   33352  https://myanimelist.net/anime/33352/Violet_Eve...
# 296      44  https://myanimelist.net/anime/44/Rurouni_Kensh...
# 297   21939  https://myanimelist.net/anime/21939/Mushishi_Z...
# 298     245  https://myanimelist.net/anime/245/Great_Teache...
# 299   40434  https://myanimelist.net/anime/40434/Mo_Dao_Zu_...
#
#                                                 images  \
# 0    {'jpg': {'image_url': 'https://cdn.myanimelist...
# 1    {'jpg': {'image_url': 'https://cdn.myanimelist...
# ...
